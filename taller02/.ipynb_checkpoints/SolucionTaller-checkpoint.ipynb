# %%
import numpy as np
from scipy import integrate as inte
import pandas as pd
import sys
import matplotlib.pyplot as plt
from bisect import bisect

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Variables y ktes

# %%
g=9.82 #gravity[m/s^2]

# %% [markdown]
# ISA (Atmósfera estandar)

# %%
def rho(hSNM):
    a=-6.5/1000 #ISA gradient [K/m]
    T0=288.15 #ISA Base temperature
    R=287 # Ideal gas kte [m^2/(s^2-K)]
    h0=0 #ISA Base heigh
    rho0=1.223 #ISA Base density
    T=T0+a*(hSNM-h0)
    rho_h=rho0*(T/T0)**((-g/(a*R))-1)
    return rho_h

# %% [markdown]
# Masa equivalente

# %%
mKart=152 #Masa del kart [kg]
mt=1.43
md=1.2
meq=mKart+mt+md
hSNM=2600

dp=11.0 # Dientes del piñon
dpl=39.0 # Dientes del plato
Nc=11/39 #Relación de transmisión
eficiencia=0.95 #Eficiencia de transmisión
rLl=0.139 #Radio geométrico llantas traseras [m]
r_et=0.98*rLl #Radio efectivo llantas traseras
cg=[-0.2231,0.4875,0.07478] #Centro de gravedad [-x,y,z] [m]
l=1.0063 #Batalla [m]
deltat=0.001 #[s]
theta=0 #Ángulo de inclinación de la pista
FrCoef=0.85 #Friction coefficient

# %% [markdown]
# Fuerzas

# %%
def peso(m):
    w=m*g
    return w

def FInclinacion(m,theta):
    Fincl=peso(m)*np.sin(theta)
    return Fincl

def Drag(v):
    d_del=0.975 #Distancia entre llantas delanteras [m]
    h=0.88 #Altura con el piloto sentado
    af=(d_del*h)/2 #Área frontal del kart
    cd=0.89 #kart Drag coeficient
    r_et=0.98*rLl
    #vomega=omega*r_et
    D=(1/2)*rho(hSNM)*af*cd*np.math.fabs(v)**2
    return D

#Se modela la rodadura como mRod*a+kteRod
def Rodadura(m,v,theta):
    A=peso(m)*(cg[0]/l)
    B=peso(m)*(1/g*(cg[2]/l)) 
    fr=0.01*(1+(v/100))# Factor de rodadura velocidad en [km/h]
    C=fr*np.cos(theta) 
    mRod=B*C
    kteRod=A*C
    return [mRod,kteRod]

def FTraccion(Te):
    Ng=Nc
    ef=eficiencia
    Ftor=Te*Ng*ef/r_et
    return Ftor

def Ffreno(coef,m,v,theta):
    A=peso(m)*(cg[0]/l)
    B=peso(m)*(1/g*(cg[2]/l)) 
    C=coef*np.cos(theta) 
    mFr=B*C
    kteFr=A*C
    return [mFr,kteFr]

def Torq (omega):
    P=3.037*((-0.00000004564538677*(omega**3))+(0.0001056995459*(omega**2))+(1.53209191*omega)-1.895523696)
    if 0<=omega<=30:
        Torque= 40
    else:
        Torque=P/(omega*2*np.pi/60)
    return Torque

# %% [markdown]
# Arranque:

# %%
def dvdtA(v,t0):
    x,vel=v
    #Constantes e inputs funciones
    omega=(vel/(r_et*eficiencia))*(60/(2*np.pi))*Nc #5000 
    mRod=Rodadura(meq,vel,theta)[0] #Masa del modelo de rodadura
    kRod=Rodadura(meq,vel,theta)[1] #Constante del modelo de Rodadura
    
    #Torque en el eje
    Te=Torq(omega)
    
    #Función a solucionar
    acel=(1/(meq+4*mRod))*(FTraccion(Te)-4*kRod-Drag(vel)-FInclinacion(meq,theta))
    
    return [vel,acel]

def solutionStart(t0,condIniciales,variacion):
    t=np.arange(t0,t0+10,deltat)
    sol=inte.odeint(dvdtA,condIniciales,t)
    if sol[-1,1]-sol[-2,1]<=variacion:
        return sol
    else:
        return np.concatenate((sol,solutionStart(t[-1],[sol[-1,0],sol[-1,1]],variacion)),axis=0)

# %%
# Variables de tiempo
t_inA=0
t_finA=100

# condiciones iniciales
x_0A=0
v_0A=0
fronteraA = [x_0A,v_0A]
tA=np.arange(t_inA,t_finA,deltat)

#Solución de la ecuación
solA=solutionStart(t_inA,[x_0A,v_0A],0.0001)

# %% [markdown]
# Frenado:

# %%
def dvdtFr(v,t0):
    x,vel=v
    mFr=Ffreno(FrCoef,meq,vel,theta)[0] #Masa del modelo de rodadura
    kFr=Ffreno(FrCoef,meq,vel,theta)[1] #Constante del modelo de Rodadura
    
    #Función a solucionar
    acel=(1/(meq+mFr))*(kFr-Drag(vel)-FInclinacion(meq,theta))
    return [vel,acel]

def solutionBreak(t0,condIniciales):
    t=np.arange(t0,t0+10,deltat)
    sol=inte.odeint(dvdtFr,condIniciales,t)
    if sol[-1,1]<=0:
        return sol
    else:
        return np.concatenate((sol,solutionBreak(t[-1],[sol[-1,0],sol[-1,1]])),axis=0)

# %%
# Variables de tiempo
t_inFr=0
t_finFr=10

# condiciones iniciales
v_0Fr=solA[-1,1]
x_0Fr=solA[-1,0]
fronteraFr = [x_0Fr,v_0Fr]
tFr=np.arange(t_inFr,t_finFr,deltat)

#Solución de la ecuación
#solFr=inte.odeint(dvdtFr,fronteraFr,tFr)
solFr=solutionBreak(t_inFr,[x_0Fr,v_0Fr])

# %% [markdown]
# Plot

# %%
#Data construction:

#Position
posA=solA[:,0][solA[:,1]<=v_0Fr]
posFr=solFr[:,0]
pos=np.append(posA,posFr) 

#Velocity
vA=solA[:,1][solA[:,1]<=v_0Fr]
vFr=solFr[:,1]
velocity=np.append(vA,vFr) #Velocity

#Acceleration
acelA=[]
acelFr=[]
#start
for v in vA:
    omega=(v/(r_et*eficiencia))*(60/(2*np.pi))*Nc #5000
    mRod=Rodadura(meq,v,theta)[0] #Masa del modelo de rodadura
    kRod=Rodadura(meq,v,theta)[1] #Constante del modelo de Rodadura
    Te=Torq(omega) 
    acelA=np.append(acelA,
                    (1/(meq+4*mRod))*(FTraccion(Te)-4*kRod-Drag(v)-FInclinacion(meq,theta)))
#Brake
for v in vFr:
    mFr=Ffreno(FrCoef,meq,v,0)[0] #Masa del modelo de rodadura
    kFr=Ffreno(FrCoef,meq,v,theta)[1] #Constante del modelo de Rodadura
    #Función a solucionar
    acelFr=np.append(acelFr,
                     (1/(meq+mFr))*(kFr-Drag(v)-FInclinacion(meq,theta)))

#DataFrame
data=pd.DataFrame=({'Time':np.arange(0,len(solA[:,0][solA[:,1]<=v_0Fr]),deltat),
                    'Position':pos,
                    'Velocity':velocity,
                    'Acceleration Start':acelA,
                    'Acceleration Brake':acelFr})
#Plot
t=data['Time'][data['Velocity']>=0]
pltPosition=data['Position'][data['Velocity']>=0]
pltVelocity=data['Velocity'][data['Velocity']>=0]
pltAccelA=data['Acceleration Start']
pltAccelFr=data['Acceleration Brake']

#Acceleration
plt.figure(1)
plt.plot(t[:len(pltAccelA)],pltAccelA)
plt.show()

plt.figure(2)
plt.plot(t[:len(pltAccelFr)],pltAccelFr)
plt.show()

plt.figure(3)
fig,ax1=plt.subplots()
ax2=ax1.twinx()
ax1.plot(t,pltPosition,'g-')
ax2.plot(t,pltVelocity,'b-')
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Position [m]', color='g')
ax2.set_ylabel('Velocity [m/s]', color='b')
plt.show()

print('tiempo total = ',t[-1],' s')
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:39: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 60002000 but corresponding boolean dimension is 80003
# tiempo total =  71.755  s

# %%
x=[1,2,3,4],[2,3,4,5]
y=[[2,4,5],[5,6,7]]
np.append(x,y)
x

# %% [markdown]
# test

# %%
omega=np.linspace(0,5000,1000)
T=[]
for n in omega:
    T=np.append(T,Torq(n))
plt.plot(omega,T)

# %%
def solutionStart(t0,condIniciales):
    t=np.arange(t0,t0+10,deltat)
    sol=inte.odeint(dvdtA,condIniciales,t)
    if sol[-1,1]-sol[-2,1]<=0.0001:
        return sol
    else:
        return solutionStart(t[-1],[sol[-1,0],sol[-1,1]])

# %%
x=solutionStart(0,[0,0])
x[-1]

# %%
solA

# %%
25*3.6
# Out:
# 90.0

# %%
90*(57/3600)
# Out:
# 1.425
